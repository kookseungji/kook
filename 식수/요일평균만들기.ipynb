# %%
total.head()
test=total[total['timestamp']<'2019-12-01']
# Out:
#     timestamp  target_value  holiday  mon  tues  wend  thurs  fri  sat  sun  \
# 0  2017-01-01             0        1    0     0     0      0    0    0    1
# 1  2017-01-02           360        0    1     0     0      0    0    0    0
# 2  2017-01-03           376        0    0     1     0      0    0    0    0
# 3  2017-01-04           396        0    0     0     1      0    0    0    0
# 4  2017-01-05           367        0    0     0     0      1    0    0    0
#
#    day_mean  day_var  month_day_mean
# 0         0        0               0
# 1         0        0               0
# 2         0        0               0
# 3         0        0               0
# 4         0        0               0

# %%
tes=test[test['target_value']!=0]

# %%
tes[tes['fri']==1]['target_value'].mean()
# Out:
# 214.45070422535213

# %%
tes[tes['fri']==1]['target_value'].var()
# Out:
# 4661.923084606933

# %%
def func(total):
    if total['mon']==1:
        return 3390.14
    elif total['tues']==1: 
        return 3808.9128
    elif total['wend']==1: 
        return 4204.8762
    elif total['thurs']==1: 
        return 3280.0395
    elif total['fri']==1: 
        return 4661.923
    else:
        return 0
        pass 
    
total.day_var=total.apply(func,axis=1)

# %%
import calendar
tes['month']=tes['timestamp'].apply(lambda x : calendar.weekday(x.month))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-91-5f42eeff6662> in <module>()
#       1 import calendar
# ----> 2 tes['month']=tes['timestamp'].apply(lambda x : calendar.weekday(x.month))
#
# ~/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    3589             else:
#    3590                 values = self.astype(object).values
# -> 3591                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3592
#    3593         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-91-5f42eeff6662> in <lambda>(x)
#       1 import calendar
# ----> 2 tes['month']=tes['timestamp'].apply(lambda x : calendar.weekday(x.month))
#
# ...

# %%
tes['timestamp']=pd.to_datetime(tes['timestamp'])
# Out:
# /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
tes.set_index('timestamp').groupby(['item_id','yoil']).resample('M').mean().round().drop('yoil',axis=1)
# Out:
#        timestamp  target_value  holiday  mon  tues  wend  thurs  fri  sat  sun
# 366   2017-01-02           360        0    1     0     0      0    0    0    0
# 367   2017-01-03           376        0    0     1     0      0    0    0    0
# 368   2017-01-04           396        0    0     0     1      0    0    0    0
# 369   2017-01-05           367        0    0     0     0      1    0    0    0
# 370   2017-01-06           301        0    0     0     0      0    1    0    0
# 373   2017-01-09           405        0    1     0     0      0    0    0    0
# 374   2017-01-10           350        0    0     1     0      0    0    0    0
# 375   2017-01-11           331        0    0     0     1      0    0    0    0
# 376   2017-01-12           436        0    0     0     0      1    0    0    0
# 377   2017-01-13           380        0    0     0     0      0    1    0    0
# 380   2017-01-16           408        0    1     0     0      0    0    0    0
# ...
