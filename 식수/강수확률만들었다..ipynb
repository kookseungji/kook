# %%
import pandas as pd
pre=pd.read_csv('rainprob_ver.csv',index_col=0)
# df0=pd.read_csv('2020_01-03강수확률.csv')
# df1=pd.read_csv('2017강수확률.csv')
# df3=pd.read_csv('2018강수확률.csv')
# df5=pd.read_csv('2019강수확률.csv')

# %%
pre.to_csv('pre_rainfall_ver.csv',index=False) 
# rainfall=pd.read_csv('강수량.csv')

# %%
pre[(pre['timestamp']>'2019-12-31')&(pre['item_id']=='중식_소계')]
# Out:
#        timestamp item_id  rainfall  rain_prob  temperature  abnormal  \
# 3467  2020-01-01   중식_소계       0.1        0.2         -2.2         0
# 3468  2020-01-02   중식_소계       0.0        0.0          1.0         0
# 3469  2020-01-03   중식_소계       0.0        0.0         -0.1         0
# 3470  2020-01-04   중식_소계       0.0        0.0          1.2         0
# 3471  2020-01-05   중식_소계       0.0        0.3          1.3         0
# 3472  2020-01-06   중식_소계       1.8        0.3          3.1         0
# 3473  2020-01-07   중식_소계      46.3        0.3          6.3         0
# 3474  2020-01-08   중식_소계      11.6        0.2          2.4         0
# 3475  2020-01-09   중식_소계       0.0        0.2         -1.2         0
# 3476  2020-01-10   중식_소계       0.0        0.2         -0.6         0
# 3477  2020-01-11   중식_소계       0.0        0.0         -0.1         0
# 3478  2020-01-12   중식_소계       0.0        0.0         -1.0         0
# 3479  2020-01-13   중식_소계       0.0        0.0         -2.9         0
# ...

# %%
len(s1)
# Out:
# 273

# %%
pre.loc[pre['timestamp']>'2019-12-31']
# Out:
#        timestamp item_id  rainfall  rain_prob  temperature  abnormal  \
# 3285  2020-01-01   석식_소계       0.1        0.3         -2.2         0
# 3286  2020-01-02   석식_소계       0.0        0.3          1.0         0
# 3287  2020-01-03   석식_소계       0.0        0.3         -0.1         0
# 3288  2020-01-04   석식_소계       0.0        0.3          1.2         0
# 3289  2020-01-05   석식_소계       0.0        0.3          1.3         0
# 3290  2020-01-06   석식_소계       1.8        0.3          3.1         0
# 3291  2020-01-07   석식_소계      46.3        0.0          6.3         0
# 3292  2020-01-08   석식_소계      11.6        0.0          2.4         0
# 3293  2020-01-09   석식_소계       0.0        0.0         -1.2         0
# 3294  2020-01-10   석식_소계       0.0        0.0         -0.6         0
# 3295  2020-01-11   석식_소계       0.0        0.0         -0.1         0
# 3296  2020-01-12   석식_소계       0.0        0.0         -1.0         0
# 3297  2020-01-13   석식_소계       0.0        0.2         -2.9         0
# ...

# %%
df0.head(10) #2020.01.01~2020.03.31
# Out:
#       format: day   hour  forecast  강수확률
# 39              1  800.0       4.0   0.3
# 187             2  800.0       4.0   0.3
# 335             3  800.0       4.0   0.0
# 483             4  800.0       4.0   0.0
# 631             5  800.0       4.0   0.2
# 779             6  800.0       4.0   0.7
# 927             7  800.0       4.0   0.9
# 1075            8  800.0       4.0   0.2
# 1223            9  800.0       4.0   0.0
# 1371           10  800.0       4.0   0.3

# %%
pre.loc[pre.timestamp>'2019-12-31','rain_prob']=np.repeat(df0['강수확률'].values,3)

# %%
df0=df0[(df0['hour']==800.0)&(df0['forecast']==4.0)]
# df1=df1[(df1['hour']==800)&(df1['forecast']==4.0)]
# df3=df3[(df3['hour']==800)&(df3['forecast']==4.0)]
# df5=df5[(df2['hour']==800)&(df5['forecast']==4.0)]

# %%
 없음(0), 비(1), 비/눈(2), 눈(3), 소나기(4)
# Out:
#      format: day   hour  forecast  value  location:58_125 Start : 20170101
# 39             1  800.0       4.0                                       0.0
# 187            2  800.0       4.0                                       0.0
# 335            3  800.0       4.0                                       0.0
# 483            4  800.0       4.0                                       0.0
# 631            5  800.0       4.0                                       0.0

# %%
df1=df1.drop(['index'],axis=1)
df3=df3.drop(['index'],axis=1)
df5=df5.drop(['index'],axis=1)

# %%
df0.rename(columns = {'value  location:58_125 Start : 20200101 ':'강수확률'},inplace = True)
# df1.rename(columns = {'value  location:58_125 Start : 20170101 ':'강수확률'},inplace = True)
# df3.rename(columns = {'value  location:58_125 Start : 20180101 ':'강수확률'},inplace = True)
# df5.rename(columns = {'value  location:58_125 Start : 20190101 ':'강수확률'},inplace = True)

# %%
df1.reset_index(inplace=True)
df3.reset_index(inplace=True)
df5.reset_index(inplace=True)

# %%
df0.강수확률=df0.강수확률.apply(lambda x: x/100)
# df1.강수확률=df1.강수확률.apply(lambda x: x/100)
# df3.강수확률=df3.강수확률.apply(lambda x: x/100)
# df5.강수확률=df5.강수확률.apply(lambda x: x/100)

# %%
df1[' format: day']=df1[' format: day'].apply(lambda x:int(x))
df3[' format: day']=df3[' format: day'].apply(lambda x:int(x))
df5[' format: day']=df5[' format: day'].apply(lambda x:int(x))

# %%
df1['year']=2017
df3['year']=2018
df5['year']=2019

# %%
df33=df3.copy()
df35=df3.copy()
df53=df5.copy()
df55=df5.copy()

# %%
d=pd.read_csv('new_rainfall_ver.csv')
d['timestamp']=pd.to_datetime(d['timestamp'])

# %%
import calendar
d['year']=d['timestamp'].apply(lambda x : x.year)

# %%
d=d.merge(nu,on='index')

# %%
nu=pd.concat([result2,rel,ri], ignore_index=True)

# %%
d.reset_index(inplace=True)

# %%
nu=nu[['index','강수확률']]

# %%
d.drop(['index'],axis=1,inplace=True)

# %%
d.to_csv('강수확률_ver.csv')
