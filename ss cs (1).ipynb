# %%
# !pip install pymysql 
import pymysql
import pandas as pd

db = pymysql.connect(
    host='ec2-13-209-223-88.ap-northeast-2.compute.amazonaws.com',  # DATABASE_HOST
    port=3306,
    user='nlpuser',  # DATABASE_USERNAME
    passwd='1234',  # DATABASE_PASSWORD
    db='nlp',  # DATABASE_NAME
    charset='utf8'
)

SQL = "SELECT review FROM Reviews where Review like '%camera%' LIMIT 1000"
data = pd.read_sql(SQL, db)
data
# Out:
# DEPRECATION: Python 2.7 will reach the end of its life on January 1st, 2020. Please upgrade your Python as Python 2.7 won't be maintained after that date. A future version of pip will drop support for Python 2.7. More details about Python 2 support in pip, can be found at https://pip.pypa.io/en/latest/development/release-process/#python-2-support
# ...
#                                                 review
# 0    While many beginner DVDs try to teach you ever...
# 1    While many beginner DVDs try to teach you ever...
# 2    I like to keep my screens clean, from my lapto...
# 3    I bought this for my husband for his birthday ...
# 4    I bought 2 of these, one for mom and one for m...
# 5    I have owned the Nook Tablet since it was rele...
# 6    The Nook was disappointing for me.  What reall...
# 7    Months later, I am still happy with this Table...
# 8    I got my Nook Tablet about two weeks ago. I co...
# 9    I went to a few places just to try testing the...
# ...

# %%
from nltk.tokenize import sent_tokenize
sent_tokenize(df['review'][0])
if [y for i in range(1000) for y in sent_tokenize(df['review'][i])] is in feature :
    return df['feature'][i] =y
else:
    pass
# Out:
#   File "<ipython-input-24-83d7e5cd5383>", line 1
#     if [y for i in range(1000) for y in df['review'][i].split() ] is in feature :
#                                                                       ^
# SyntaxError: invalid syntax

# %%
feature={'1':(resolution)|(pixel)|(megapixel),
         '2':(lens)|(wide angle)|(normal range),
         '3':(optical)|(zoom)|(optical zoom)|(digital zoom),
         '4'memory':'megabytes','MB',
         5'burst':'continuous','shutter','recovery','motion','sport',
         6'battery':'batteries','power',
         7'focus':'exposure','manual','iso',
         8'LCD':'LCD','screen',
         9'compression':'compression','compress','jpeg',
         10'flash':'flash','light'}

# %%
import nltk
nltk.download('punkt')
from nltk.tokenize import sent_tokenize
y=[y for i in range(1000) for y in sent_tokenize(df['review'][i])]
# Out:
# [nltk_data] Downloading package punkt to /home/lab05/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
feature={1:['pixel','megapixel','resolution'],
         2:['lens','wide angle','normal range'],
         3:['optical','zoom','optical zoom','digital zoom'],
         4:['memory','megabytes','MB']
        }
       
[line for line in y if line.find(feature.get(1)[0])]
# Out:
# ['While many beginner DVDs try to teach you everything there is to know about Photoshop CS5, this introductory course shows you the critical things you need to know to start feeling confident in your Photoshop skills.',
#  'Bestselling author and Photoshop trainer, Matt Kloskowski shows you exactly what you need to know about tools, filters, adjustments, palettes, and menu items to hit the ground running in Photoshop.',
#  "These include: layers and how they're key to mastering Photoshop, selections and the essential tools you really need to worry about, getting started with Camera Raw and which Retouching tools you'll find the most helpful.",
#  "When you're done with this DVD you'll have a solid grasp of the most important features and be at the next level in no time.",
# ...

# %%
[[line for line in y ][0] for line in y if [line for line in y ][0].find(feature.get(1)[0])]
# Out:
# ['While many beginner DVDs try to teach you everything there is to know about Photoshop CS5, this introductory course shows you the critical things you need to know to start feeling confident in your Photoshop skills.',
#  'While many beginner DVDs try to teach you everything there is to know about Photoshop CS5, this introductory course shows you the critical things you need to know to start feeling confident in your Photoshop skills.',
#  'While many beginner DVDs try to teach you everything there is to know about Photoshop CS5, this introductory course shows you the critical things you need to know to start feeling confident in your Photoshop skills.',
#  'While many beginner DVDs try to teach you everything there is to know about Photoshop CS5, this introductory course shows you the critical things you need to know to start feeling confident in your Photoshop skills.',
# ...

# %%
import nltk
nltk.download('comparative_sentences')
from nltk.corpus import comparative_sentences
comparison = comparative_sentences.keywords_readme()
comparison
f = pd.DataFrame(columns=['review_index','sentence','FeatureName','FeatureNameRe','comparison'])
for idx, one_review in enumerate(data['review']):
    sentences = sent_tokenize(one_review)
    for sentence in sentences:
        tokens = word_tokenize(sentence)
        for token in tokens:
            for j in range(10):
                if token in feature[str(j)]:
                    df = df.append(pd.DataFrame([[idx, sentence, j+1,FeatureNameRe[str(j+1)] ]], columns=['review_index','sentence','FeatureName','FeatureNameRe']), ignore_index=True)
                else:
                    pass
df = df.dropna(axis=0)
df = df.drop_duplicates(['review_index','FeatureName'], keep='last')
df = df.reset_index(drop=True)
# Out:
# [nltk_data] Downloading package comparative_sentences to
# [nltk_data]     /home/lab05/nltk_data...
# [nltk_data]   Package comparative_sentences is already up-to-date!
# ['POS tag JJR //adjective, comparative',
#  'POS tag RBR //adverb, comparative',
#  'POS tag JJS //adjective, superlative',
#  'POS tag RBS //adjective, superlative',
#  'as <word> as //e.g. as good as',
#  'beat',
#  'inferior',
#  'outstrip',
#  'both',
#  'on par with',
#  'Choice',
#  'choose',
#  'prefer',
#  'recommend',
#  'outperform',
#  'superior',
#  'all',
#  'up against',
#  'less',
#  'favor',
#  'defeat',
#  'twice',
#  'thrice',
#  'half',
#  'same',
#  'either',
#  'Compete',
#  'Number one',
#  'one of few',
#  'more',
#  'like',
#  'behind',
#  'similar',
#  'identical',
#  'Versus',
#  'first',
#  'outdistance',
#  'before',
#  'double',
#  'outsell',
#  'nobody',
#  'Vs',
#  'last',
#  'after',
#  'thrice',
#  'improve',
#  'equal',
#  'equivalent',
#  'together',
#  'altogether',
# ...

# %%
# !pip install pymysql 
import pymysql
import pandas as pd

db = pymysql.connect(
    host='ec2-13-209-223-88.ap-northeast-2.compute.amazonaws.com',  # DATABASE_HOST
    port=3306,
    user='nlpuser',  # DATABASE_USERNAME
    passwd='1234',  # DATABASE_PASSWORD
    db='nlp',  # DATABASE_NAME
    charset='utf8'
)

SQL = "SELECT * FROM TotalDic LIMIT 1000"
d1f = pd.read_sql(SQL, db)
d1f
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-123-efae0aa49722> in <module>
# ----> 1 get_ipython().system('pip install pymysql ')
#       2 import pymysql
#       3 import pandas as pd
#       4
#       5 db = pymysql.connect(
#
# /usr/local/lib/python3.5/dist-packages/IPython/core/interactiveshell.py in system_piped(self, cmd)
#    2444         # a non-None value would trigger :func:`sys.displayhook` calls.
#    2445         # Instead, we store the exit_code in user_ns.
# -> 2446         self.user_ns['_exit_code'] = system(self.var_expand(cmd, depth=1))
#    2447
#    2448     def system_raw(self, cmd):
#
# /usr/local/lib/python3.5/dist-packages/IPython/utils/_process_posix.py in system(self, cmd)
#     154                 child = pexpect.spawnb(self.sh, args=['-c', cmd]) # Pexpect-U
#     155             else:
# ...

# %%
import pandas as pd
from nltk.tokenize import sent_tokenize
from nltk.tokenize import word_tokenize
feature={
   '0': ['resolution', 'pixel', 'megapixel'],
   '1': ['lens','wide angle','normal range'],
   '2': ['optical','zoom','optical zoom','digital zoom'],
   '3': ['memory','megabytes','MB'],
   '4': ['burst','continuous','shutter','recovery','motion','sport'],
   '5': ['battery','batteries','power'],
   '6': ['focus','exposure','manual','iso'],
   '7': ['LCD','screen'],
   '8': ['compression','compress','jpeg'],
   '9': ['flash','light']
}
FeatureNameRe={
   '1': '(resolution)|(pixel)|(megapixel)',
   '2': '(lens)|(wide angle)|(normal range)',
   '3': '(optical)|(zoom)|(optical zoom)|(digital zoom)',
   '4': '(memory)|(megabytes)|(MB)',
   '5': '(burst)|(continuous)|(shutter)|(recovery)|(motion)|(sport)',
   '6': '(battery)|(batteries)|(power)',
   '7': '(focus)|(exposure)|(manual)|(iso)|(ISO)',
   '8': '(LCD)|(screen)',
   '9': '(compression)|(compress)|(jpeg)',
   '10': '(flash)|(light)'
}
index_list = ['0','1','2']
df = pd.DataFrame(columns=['review_index','sentence','FeatureName','FeatureNameRe',])
for idx, one_review in enumerate(data['review']):
    sentences = sent_tokenize(one_review)
    for sentence in sentences:
        tokens = word_tokenize(sentence)
        for token in tokens:
            for j in range(10):
                if token in feature[str(j)]:
                    df = df.append(pd.DataFrame([[idx, sentence, j+1,FeatureNameRe[str(j+1)] ]], columns=['review_index','sentence','FeatureName','FeatureNameRe']), ignore_index=True)
                else:
                    pass
df = df.dropna(axis=0)
df = df.drop_duplicates(['review_index','FeatureName'], keep='last')
df = df.reset_index(drop=True)

# %%
# !pip install pymysql 
import pymysql
import pandas as pd

db = pymysql.connect(
    host='ec2-13-209-223-88.ap-northeast-2.compute.amazonaws.com',  # DATABASE_HOST
    port=3306,
    user='nlpuser',  # DATABASE_USERNAME
    passwd='1234',  # DATABASE_PASSWORD
    db='nlp',  # DATABASE_NAME
    charset='utf8'
)
SQL = "SELECT * FROM Reviews where Review like '%camera%' limit 1000"
df1 = pd.read_sql(SQL, db)
df1
SQL = "SELECT * FROM meta"
dfm = pd.read_sql(SQL, db)
# Out:
# DEPRECATION: Python 2.7 will reach the end of its life on January 1st, 2020. Please upgrade your Python as Python 2.7 won't be maintained after that date. A future version of pip will drop support for Python 2.7. More details about Python 2 support in pip, can be found at https://pip.pypa.io/en/latest/development/release-process/#python-2-support
# ...

# %%
dfm
# Out:
#                                                     imUrl  \
# 0       http://ecx.images-amazon.com/images/I/31JIPhp%...
# 1       http://ecx.images-amazon.com/images/I/31uogm6Y...
# 2       http://ecx.images-amazon.com/images/I/51k0qa8f...
# 3       http://ecx.images-amazon.com/images/I/41HaAhbv...
# 4       http://ecx.images-amazon.com/images/I/51FnRkJq...
# 5       http://ecx.images-amazon.com/images/I/21rEirnd...
# 6       http://ecx.images-amazon.com/images/I/41kQsHT8...
# 7       http://ecx.images-amazon.com/images/I/41CqeMM0...
# 8       http://ecx.images-amazon.com/images/I/31KkpByX...
# 9       http://g-ecx.images-amazon.com/images/G/01/x-s...
# 10      http://ecx.images-amazon.com/images/I/51PnHXdX...
# 11      http://g-ecx.images-amazon.com/images/G/01/x-s...
# 12      http://ecx.images-amazon.com/images/I/21YJXPCz...
# 13      http://ecx.images-amazon.com/images/I/01eX9rjx...
# 14      http://ecx.images-amazon.com/images/I/41-ZZ1e7...
# ...

# %%
dfm['title'][17]
# Out:
# 'Barnes Noble Nook Simple Touch Reader BRNV300+Lewis Cover'

# %%
SQL = "SELECT * FROM meta where title like '%camera%' limit 1000"
m = pd.read_sql(SQL, db)
m
# Out:
#                                                  imUrl  \
# 0    http://ecx.images-amazon.com/images/I/41oMtO-S...
# 1    http://ecx.images-amazon.com/images/I/31kTkbrG...
# 2    http://ecx.images-amazon.com/images/I/418dRA4S...
# 3    http://ecx.images-amazon.com/images/I/511u-8bI...
# 4    http://ecx.images-amazon.com/images/I/51Z%2B11...
# 5    http://ecx.images-amazon.com/images/I/51ng54e-...
# 6    http://ecx.images-amazon.com/images/I/41eA1D6z...
# 7    http://ecx.images-amazon.com/images/I/41agMSjk...
# 8    http://ecx.images-amazon.com/images/I/51CGN3uR...
# 9    http://ecx.images-amazon.com/images/I/2110JA8S...
# 10   http://ecx.images-amazon.com/images/I/31gIkW8h...
# 11   http://ecx.images-amazon.com/images/I/41R%2BbY...
# 12   http://ecx.images-amazon.com/images/I/41D9ipp8...
# 13   http://ecx.images-amazon.com/images/I/41Fx-Lg6...
# 14   http://ecx.images-amazon.com/images/I/418g%2B8...
# 15   http://ecx.images-amazon.com/images/I/31nPK7sR...
# ...

# %%
df1.rename(columns ={'ASIN':'asin'},inplace=True)

# %%
import nltk
nltk.download('comparative_sentences')
from nltk.corpus import comparative_sentences
comparison = comparative_sentences.keywords_readme()
comparison
# Out:
# [nltk_data] Downloading package comparative_sentences to
# [nltk_data]     /home/lab05/nltk_data...
# [nltk_data]   Package comparative_sentences is already up-to-date!
# ['POS tag JJR //adjective, comparative',
#  'POS tag RBR //adverb, comparative',
#  'POS tag JJS //adjective, superlative',
#  'POS tag RBS //adjective, superlative',
#  'as <word> as //e.g. as good as',
#  'beat',
#  'inferior',
#  'outstrip',
#  'both',
#  'on par with',
#  'Choice',
#  'choose',
#  'prefer',
#  'recommend',
#  'outperform',
#  'superior',
#  'all',
#  'up against',
#  'less',
#  'favor',
#  'defeat',
#  'twice',
#  'thrice',
#  'half',
#  'same',
#  'either',
#  'Compete',
#  'Number one',
#  'one of few',
#  'more',
#  'like',
#  'behind',
#  'similar',
#  'identical',
#  'Versus',
#  'first',
#  'outdistance',
#  'before',
#  'double',
#  'outsell',
#  'nobody',
#  'Vs',
#  'last',
#  'after',
#  'thrice',
#  'improve',
#  'equal',
#  'equivalent',
#  'together',
#  'altogether',
# ...

# %%
for i in range():
    if [token for token in tokens][i] in comparison:
        df.append()
# Out:
# 'I'

# %%
for i in range(110):
    sent_tokenize(df['sentence'])
# Out:
# 0       I still use my bottle of cleaning liquid and c...
# 1       It is pretty much useless in its stock form un...
# 2       currently bluetooth is not enabled but when it...
# 3       The only downfall to using it is that it lags ...
# 4       The screen is nice, but the body feels a littl...
# 5       Other reading options are Go to Page, Back, Fi...
# 6       It's also really easy to view the screen from ...
# 7       Also the response on the touch screen was grea...
# 8       Also the response on the touch screen was grea...
# 9       But unlike other tablets where if you crack th...
# 10      The color is amazing and the screen is super f...
# 11                          Why pay over $1K if no flash?
# 12      At home I can just watch Netflix on the big sc...
# 13      I bought a Nook Tablet based on the principle ...
# 14      The newer version is faster, has a higher reso...
# 15      (They also make a version with a larger screen...
# ...

# %%
list=[]
for j in range(1000):
    for i in range(len(word_tokenize(df['sentence'][j]))):
        if [i for i in word_tokenize(df['sentence'][j])] in comparison:
            print('cs')
        else:
            print('ss')
# Out:
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ss
# ...

# %%
for j in range(1000):
    for i in range(len(word_tokenize(df['sentence'][j]))):
        [i for i in word_tokenize(df['sentence'][j])]

# %%
JJR,RBR,JJS,RBS 
import nltk
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
simpleSentence = df['sentence'][0]
token=nltk.word_tokenize(simpleSentence)
withTags = nltk.pos_tag(token)
print(withTags)
# Out:
# [('I', 'PRP'), ('still', 'RB'), ('use', 'VBP'), ('my', 'PRP$'), ('bottle', 'NN'), ('of', 'IN'), ('cleaning', 'VBG'), ('liquid', 'NN'), ('and', 'CC'), ('cleaning', 'NN'), ('clothes', 'NNS'), ('for', 'IN'), ('my', 'PRP$'), ('flat', 'JJ'), ('screen', 'NN'), ('television', 'NN'), ('since', 'IN'), ('it', 'PRP'), ('is', 'VBZ'), ('too', 'RB'), ('big', 'JJ'), ('for', 'IN'), ('these', 'DT'), ('small', 'JJ'), ('tissues', 'NNS'), ('.', '.')]
# [nltk_data] Downloading package punkt to /home/lab05/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /home/lab05/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %%
len(word_tokenize(df['sentence'][0]))
# Out:
# 26

# %%
df1=df1.drop(0).drop(1)

# %% [markdown]
# df1_copy.head

# %%
df1_copy=df1.copy()

# %%
df1_copy.rename(columns={'index','review_index'},inplace=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-102-171b6b6862d1> in <module>
#       1
# ----> 2 df1_copy.rename(columns={'index','review_index'},inplace=True)
#
# /usr/local/lib/python3.5/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     195         @wraps(func)
#     196         def wrapper(*args, **kwargs):
# --> 197             return func(*args, **kwargs)
#     198
#     199         if not PY2:
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/frame.py in rename(self, *args, **kwargs)
#    4023         kwargs.pop('axis', None)
#    4024         kwargs.pop('mapper', None)
# -> 4025         return super(DataFrame, self).rename(**kwargs)
#    4026
#    4027     @Substitution(**_shared_doc_kwargs)
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/generic.py in rename(self, *args, **kwargs)
# ...

# %%
df
# Out:
#      review_index                                           sentence  \
# 0               2  I still use my bottle of cleaning liquid and c...
# 1               3  It is pretty much useless in its stock form un...
# 2               4  currently bluetooth is not enabled but when it...
# 3               5  The only downfall to using it is that it lags ...
# 4               6  The screen is nice, but the body feels a littl...
# 5               7  Other reading options are Go to Page, Back, Fi...
# 6               8  It's also really easy to view the screen from ...
# 7               9  Also the response on the touch screen was grea...
# 8               9  Also the response on the touch screen was grea...
# 9               9  But unlike other tablets where if you crack th...
# 10             10  The color is amazing and the screen is super f...
# 11             10                      Why pay over $1K if no flash?
# 12             11  At home I can just watch Netflix on the big sc...
# ...

# %%
음=pd.merge(df,df1_copy,left_index=True,right_index=True,how='outer')

# %%
음['sentence'][0]
# Out:
# 'I still use my bottle of cleaning liquid and cleaning clothes for my flat screen television since it is too big for these small tissues.'

# %%
음['Review'][2]
# Out:
# "I like to keep my screens clean, from my laptop to my iPod, GPS, Kindle, digital cameras and more. However it can be difficult when traveling since I don't want to carry bottles of cleaning fluid in my luggage.  These pre-packaged wipes are really nice to have an easy to carry around.First I start with the wet wipe to remove grease and dirt, then I remove the moisture with the dry wipe.  You want to practice with it in order to not leave any streaks but it's not too difficult to do. The wet wipes are not only good for screens but they take figure prints off the exterior on my laptop.  I still use my bottle of cleaning liquid and cleaning clothes for my flat screen television since it is too big for these small tissues.  However, for traveling these are great!"

# %%
음.head()
# Out:
#   review_index                                           sentence FeatureName  \
# 0            2  I still use my bottle of cleaning liquid and c...           8
# 1            3  It is pretty much useless in its stock form un...          10
# 2            4  currently bluetooth is not enabled but when it...           8
# 3            5  The only downfall to using it is that it lags ...           6
# 4            6  The screen is nice, but the body feels a littl...           8
#
#                    FeatureNameRe  ReviewID  CategoryID ProductID        asin  \
# 0                 (LCD)|(screen)       NaN         NaN       NaN         NaN
# 1                (flash)|(light)       NaN         NaN       NaN         NaN
# 2                 (LCD)|(screen)     205.0         1.0      None  0970407998
# 3  (battery)|(batteries)|(power)    1356.0         1.0      None  1400501466
# 4                 (LCD)|(screen)    1367.0         1.0      None  1400501466
#
# ...
