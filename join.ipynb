# %%
import numpy as np
import pandas as pd

# %%
pd.Series(['a','b',c,1,2,3])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-6419caff6a9a> in <module>
# ----> 1 pd.Series(['a','b',c,1,2,3])
#
# NameError: name 'c' is not defined

# %%
pd.date_range(start='2019-01-01',end='2019-01-01')
# Out:
# DatetimeIndex(['2019-01-01'], dtype='datetime64[ns]', freq='D')

# %%
pd.date_range(start='2019-01-01', periods = 4, freq = '2D')#이틀마다 4개
pd.date_range(start='2019-01-01', periods = 4, freq = 'W') #한 주마다 4개
# Out:
# DatetimeIndex(['2019-01-06', '2019-01-13', '2019-01-20', '2019-01-27'], dtype='datetime64[ns]', freq='W-SUN')

# %%
pd.date_range(start='2019-01-01', periods = 12, freq = '2M')
# Out:
# DatetimeIndex(['2019-01-31', '2019-03-31', '2019-05-31', '2019-07-31',
#                '2019-09-30', '2019-11-30', '2020-01-31', '2020-03-31',
#                '2020-05-31', '2020-07-31', '2020-09-30', '2020-11-30'],
#               dtype='datetime64[ns]', freq='2M')

# %%
KTX_data = {'경부선 KTX': [39060, 39896, 42005, 43621, 41702, 41266, 32427],
            '호남선 KTX': [7313, 6967, 6873, 6626, 8675, 10622, 9228],
            '경전선 KTX': [3627, 4168, 4088, 4424, 4606, 4984, 5570],
            '전라선 KTX': [309, 1771, 1954, 2244, 3146, 3945, 5766],
            '동해선 KTX': [np.nan,np.nan, np.nan, np.nan, 2395, 3786, 6667]}
col_list = ['경부선 KTX','호남선 KTX','경전선 KTX','전라선 KTX','동해선 KTX']
index_list = ['2011', '2012', '2013', '2014', '2015', '2016', '2017']

df_KTX = pd.DataFrame(KTX_data, columns = col_list, index = index_list)
df_KTX
# Out:
#       경부선 KTX  호남선 KTX  경전선 KTX  전라선 KTX  동해선 KTX
# 2011    39060     7313     3627      309      NaN
# 2012    39896     6967     4168     1771      NaN
# 2013    42005     6873     4088     1954      NaN
# 2014    43621     6626     4424     2244      NaN
# 2015    41702     8675     4606     3146   2395.0
# 2016    41266    10622     4984     3945   3786.0
# 2017    32427     9228     5570     5766   6667.0

# %%
pd.DataFrame(df_KTX['경부선 KTX']['2012':'2016'])
# Out:
#       경부선 KTX
# 2012    39896
# 2013    42005
# 2014    43621
# 2015    41702
# 2016    41266

# %%
df_KTX.loc['2016':'2017','경부선 KTX':'전라선 KTX']
# Out:
#       경부선 KTX  호남선 KTX  경전선 KTX  전라선 KTX
# 2016    41266    10622     4984     3945
# 2017    32427     9228     5570     5766

# %%
df_KTX.T
# Out:
#             2011     2012     2013     2014     2015     2016     2017
# 경부선 KTX  39060.0  39896.0  42005.0  43621.0  41702.0  41266.0  32427.0
# 호남선 KTX   7313.0   6967.0   6873.0   6626.0   8675.0  10622.0   9228.0
# 경전선 KTX   3627.0   4168.0   4088.0   4424.0   4606.0   4984.0   5570.0
# 전라선 KTX    309.0   1771.0   1954.0   2244.0   3146.0   3945.0   5766.0
# 동해선 KTX      NaN      NaN      NaN      NaN   2395.0   3786.0   6667.0

# %%
df1 = pd.DataFrame({'Class1': [95, 92, 98, 100],
                    'Class2': [91, 93, 97, 99]})
df1
# Out:
#    Class1  Class2
# 0      95      91
# 1      92      93
# 2      98      97
# 3     100      99

# %%
df2 = pd.DataFrame({'Class1': [87, 89],
                    'Class2': [85, 90]})
df2
# Out:
#    Class1  Class2
# 0      87      85
# 1      89      90

# %%
df1.append(df2,ignore_index=True)
# Out:
#    Class1  Class2
# 0      95      91
# 1      92      93
# 2      98      97
# 3     100      99
# 4      87      85
# 5      89      90

# %%
df3 = pd.DataFrame({'Class1': [96, 83]})
df3
# Out:
#    Class1
# 0      96
# 1      83

# %%
df2.append(df3,ignore_index=True) #NaN됨
# Out:
#    Class1  Class2
# 0      87    85.0
# 1      89    90.0
# 2      96     NaN
# 3      83     NaN

# %%
df4 = pd.DataFrame({'Class3': [93, 91, 95, 98]})
df4
df1.join(df4) #index 같은 것끼리 들어감
# Out:
#    Class1  Class2  Class3
# 0      95      91      93
# 1      92      93      91
# 2      98      97      95
# 3     100      99      98

# %%
index_label = ['a','b','c','d']
df1a = pd.DataFrame({'Class1': [95, 92, 98, 100],
                    'Class2': [91, 93, 97, 99]}, index= index_label)
df4a = pd.DataFrame({'Class3': [93, 91, 95, 98]}, index=['d','c','b','0'])

df1a.join(df4a)
# Out:
#    Class1  Class2  Class3
# a      95      91     NaN
# b      92      93    95.0
# c      98      97    91.0
# d     100      99    93.0

# %%
df5 = pd.DataFrame({'Class4': [82, 92]})

# %%
df1.join(df5)
# Out:
#    Class1  Class2  Class4
# 0      95      91    82.0
# 1      92      93    92.0
# 2      98      97     NaN
# 3     100      99     NaN

# %%
df11=pd.DataFrame({'Class3':[80,20,65,70]})
df22=pd.DataFrame({'Class4':[70,20,65,80]})
df3.join(df11).join(df22) #df3=2줄이라서 2줄
df22.join(df11).join(df3) #df22=4줄이라서 4줄
df3.join(df11,how='right').join(df22)
# Out:
#    Class1  Class3  Class4
# 0    96.0      80      70
# 1    83.0      20      20
# 2     NaN      65      65
# 3     NaN      70      80

# %%
dfAB = pd.DataFrame({'판매월': ['1월', '2월', '3월', '4월'],
                       '제품A': [100, 150, 200, 130],
                       '제품B': [90, 110, 140, 170]})

dfCD = pd.DataFrame({'판매월': ['1월', '2월', '3월', '4월'],
                       '제품C': [112, 141, 203, 134],
                       '제품D': [90, 110, 140, 170]})
dfCD
# Out:
#   판매월  제품C  제품D
# 0  1월  112   90
# 1  2월  141  110
# 2  3월  203  140
# 3  4월  134  170

# %%
dfAB.merge(dfCD)
# Out:
#   판매월  제품A  제품B  제품C  제품D
# 0  1월  100   90  112   90
# 1  2월  150  110  141  110
# 2  3월  200  140  203  140
# 3  4월  130  170  134  170

# %%
dfl = pd.DataFrame({'key':['A','B','C'], 'left': [1, 2, 3]})
dfl
# Out:
#   key  left
# 0   A     1
# 1   B     2
# 2   C     3

# %%
dfr = pd.DataFrame({'key':['A','B','D'], 'right': [4, 5, 6]})
dfr
# Out:
#   key  right
# 0   A      4
# 1   B      5
# 2   D      6

# %%
dfl.merge(dfr,how='left',on='key')
# Out:
#   key  left  right
# 0   A     1    4.0
# 1   B     2    5.0
# 2   C     3    NaN

# %%
pd.read_excel('C:\\Users\\student\\Desktop\\학생시험성적.xlsx',index_col='학생')
# Out:
#     국어  영어  수학         평균
# 학생
# A   80  90  85  85.000000
# B   90  95  95  93.333333
# C   95  70  75  80.000000
# D   70  85  80  78.333333
# E   75  90  85  83.333333

# %%
exam2 = {'학생': ['A', 'B', 'C', 'D', 'E', 'F'],
                    '국어': [85, 95, 75, 80, 85, 100],
                    '영어': [80, 90, 95, 70, 75, 85],
                    '수학': [90, 95, 70, 85, 90, 95]}
df1=pd.DataFrame(exam2)
excel_writer = pd.ExcelWriter('C:\\Users\\student\\Desktop\\학생시험성적2.xlsx', engine='xlsxwriter')
df1.to_excel(excel_writer, index=False)
excel_writer.save()
# Out:
#   학생   국어  영어  수학
# 0  A   85  80  90
# 1  B   95  90  95
# 2  C   75  95  70
# 3  D   80  70  85
# 4  E   85  75  90
# 5  F  100  85  95

# %%
import glob
excel_data_files = glob.glob('C:\\Users\\student\Desktop\담당자별_판매량_*사원.xlsx')

# %%
for idx,f in enumerate(excel_data_files):
    f=pd.read_excel(f)
    
    df=pd.DataFrame(f)
    if idx==0 :
        total_data=df
    else:
        total_data=total_data.append(df)
        
df=total_data.reset_index(drop=True)

# %%
df
# Out:
#    제품명 담당자 지역  1분기  2분기  3분기  4분기
# 0   시계   B  나  154  108  155  114
# 1   구두   B  나  200  223  213  202
# 2  핸드백   B  나  350  340  377  392
# 3   시계   C  다  168  102  149  174
# 4   구두   C  다  231  279  277  292
# 5  핸드백   C  다  365  383  308  323

# %%
df.loc[:2,'담당자']='Andy'

# %%
df['담당자']='An'

# %%
df
# Out:
#    제품명 담당자 지역  1분기  2분기  3분기  4분기 (1, 담당자)
# 0   시계  An  다  168  102  149  174     Andy
# 1   구두  An  다  231  279  277  292     Andy
# 2  핸드백  An  다  365  383  308  323     Andy

# %%
df[df['제품명']=='시계']
# Out:
#   제품명 담당자 지역  1분기  2분기  3분기  4분기
# 0  시계   B  나  154  108  155  114
# 3  시계   C  다  168  102  149  174

# %%
df[df['제품명'].isin(['핸드백'])]#제품명 속 이름'핸드백'인거
# Out:
#    제품명 담당자 지역  1분기  2분기  3분기  4분기
# 2  핸드백   B  나  350  340  377  392
# 5  핸드백   C  다  365  383  308  323

# %%
df[(df['3분기']>=150) & (df['제품명']=='핸드백')]
# Out:
#    제품명 담당자 지역  1분기  2분기  3분기  4분기
# 2  핸드백   B  나  350  340  377  392
# 5  핸드백   C  다  365  383  308  323

# %%
temp=lambda x:x*3

# %%
df['1분기'].apply(lambda x:x*2)
# Out:
# 0    308
# 1    400
# 2    700
# 3    336
# 4    462
# 5    730
# Name: 1분기, dtype: int64

# %%
df = pd.read_csv('Ecommerce Purchases.txt',encoding='cp949',)
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-218-f0bfcab54641> in <module>
# ----> 1 df = pd.read_csv('Ecommerce Purchases.txt',encoding='cp949')
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
# ...

# %%
df
# Out:
#                             Address              Lot AM or PM  \
# 0          16629 Pace Camp Apt. 448              NaN      NaN
# 1                     Alexisborough   NE 77130-7478"    46 in
# 2      9374 Jasmine Spurs Suite 508              NaN      NaN
# 3                        South John   TN 84355-4179"    28 rn
# 4                Unit 0065 Box 5052              NaN      NaN
# 5                     DPO AP 27450"            94 vE       PM
# 6                  7780 Julia Fords              NaN      NaN
# 7                         New Stacy        WA 45798"    36 vm
# 8       23012 Munoz Drive Suite 337              NaN      NaN
# 9                       New Cynthia        TX 57826"    20 IE
# 10     7502 Powell Mission Apt. 768              NaN      NaN
# 11                       Travisland   VA 30493-5334"    21 XT
# 12            93971 Conway Causeway              NaN      NaN
# 13                    Andersonburgh        AZ 75107"    96 Xt
# ...
